# %% [markdown]
# ## Xgboost-demo-1
# ### 1、Dmatrix保存为二进制文件
# 可以将完成特征处理并且已经转换为DMatrix格式的数据进行保存，下次加载时可以直接使用

# %%
import xgboost as xgb
import numpy as np
import pandas as pd
from sklearn import datasets
from sklearn.model_selection import train_test_split

# %%
#加载乳腺癌数据
cancer = datasets.load_breast_cancer()
X = cancer.data
y = cancer.target
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.2,random_state = 8)

# %%
xgb_train = xgb.DMatrix(X_train,label=y_train)
xgb_test = xgb.DMatrix(X_test,label=y_test)

# %%
params = {
    'objective': "binary:logistic",
    'booster': "gbtree",
    'eta': 0.1,
    'min_child_weight': 1,
    'max_depth': 5
    }
num_round = 10
watchlist = [(xgb_train,'train'),(xgb_test,'test')]
model = xgb.train(params,xgb_train,num_round,evals = watchlist)
preds = model.predict(xgb_test)
# Out:
# [0]	train-error:0.024176	test-error:0.035088
# [1]	train-error:0.015385	test-error:0.052632
# [2]	train-error:0.013187	test-error:0.070175
# [3]	train-error:0.004396	test-error:0.078947
# [4]	train-error:0.004396	test-error:0.078947
# [5]	train-error:0.004396	test-error:0.04386
# [6]	train-error:0.004396	test-error:0.052632
# [7]	train-error:0.004396	test-error:0.061404
# [8]	train-error:0.004396	test-error:0.052632
# [9]	train-error:0.004396	test-error:0.04386

# %%
xgb_test.save_binary('dtest.buffer') #保存为二进制文件
xgb_test2 = xgb.DMatrix('dtest.buffer')
preds2 = model.predict(xgb_test2) #利用新数据预测
# Out:
# [02:02:41] 114x30 matrix with 3420 entries loaded from dtest.buffer

# %%
preds==preds2
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True])

# %% [markdown]
# ### 2、基于历史预测值训练
# 在历史预测值上训练，可以使模型快速达到较高的准确度，节省时间，这里的预测值为未进行转化（如：softmax、sigmoid）的原始值

# %%
#训练模型
bst = xgb.train(params,xgb_train,10,watchlist)

#设置output_margin = True,表示最终输出的预测值为未进行sigmoid转化的原始值
pred_train = bst.predict(xgb_train,output_margin = True)
pred_test = bst.predict(xgb_test,output_margin=True)

#设置预测值为初始值
xgb_train.set_base_margin(pred_train)
xgb_test.set_base_margin(pred_test)

print('以下是设置预测值为初始值的运行结果：')
bst = xgb.train(params,xgb_train,10,watchlist)
# Out:
# [0]	train-error:0.024176	test-error:0.035088
# [1]	train-error:0.015385	test-error:0.052632
# [2]	train-error:0.013187	test-error:0.070175
# [3]	train-error:0.004396	test-error:0.078947
# [4]	train-error:0.004396	test-error:0.078947
# [5]	train-error:0.004396	test-error:0.04386
# [6]	train-error:0.004396	test-error:0.052632
# [7]	train-error:0.004396	test-error:0.061404
# [8]	train-error:0.004396	test-error:0.052632
# [9]	train-error:0.004396	test-error:0.04386
# 以下是设置预测值为初始值的运行结果：
# [0]	train-error:0.004396	test-error:0.04386
# [1]	train-error:0.004396	test-error:0.04386
# [2]	train-error:0.004396	test-error:0.04386
# [3]	train-error:0.004396	test-error:0.04386
# [4]	train-error:0.004396	test-error:0.035088
# [5]	train-error:0.004396	test-error:0.035088
# [6]	train-error:0.004396	test-error:0.035088
# [7]	train-error:0.004396	test-error:0.04386
# [8]	train-error:0.004396	test-error:0.04386
# [9]	train-error:0.004396	test-error:0.04386

# %% [markdown]
# ### 3、自定义目标函数和评估函数
# xgboost的自定义函数需要***返回一阶、二阶梯度***，即需要**满足二次可微**，通过自定义目标函数得到的预测值是模型预测的原始值，不会进行任何转换，自定义目标函数后，xgboost内置的评估函数不一定适用，因为内置的评估函数默认是经过转换的（sigmoid、softmax）

# %%
import xgboost as xgb
import numpy as np
import pandas as pd
from sklearn import datasets
from sklearn.model_selection import train_test_split

# %%
cancer = datasets.load_breast_cancer()
X = cancer.data
y = cancer.target
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.2,random_state = 8)

# %%
xgb_train = xgb.DMatrix(X_train,label=y_train)
xgb_test = xgb.DMatrix(X_test,label=y_test)

# %%
params = {
    "booster": "gbtree",
    "eta": 0.1,
    "max_depth": 5
}
num_round = 50
watchlist = [(xgb_train,'train'),(xgb_test,'test')]

# %%
#自定义目标函数logloss，给定预测值，返回一阶、二阶梯度
def logregobj(preds,dtrain):
  labels = dtrain.get_label() #真实值
  preds = 1.0/ (1.0 + np.exp(-preds)) #预测值
  grad = preds - labels   #一阶导数 
  hess = preds * (1.0 - preds)
  return grad,hess

# %%
#自定义评估函数
def evalerror(preds, dtrain):
  labels = dtrain.get_label()
  #因为是未进行sigmoid转换，因此以0为分类阈值
  return 'error', float(sum(labels != (preds > 0.0)))/ len(labels)

# %%
bst = xgb.train(params,xgb_train,num_round,watchlist,obj=logregobj,feval=evalerror)
# Out:
# [0]	train-rmse:0.336644	test-rmse:0.352463	train-error:0.364835	test-error:0.403509
# [1]	train-rmse:0.216709	test-rmse:0.253139	train-error:0.364835	test-error:0.403509
# [2]	train-rmse:0.171317	test-rmse:0.230497	train-error:0.048352	test-error:0.078947
# [3]	train-rmse:0.237105	test-rmse:0.290008	train-error:0.048352	test-error:0.087719
# [4]	train-rmse:0.337897	test-rmse:0.383917	train-error:0.035165	test-error:0.078947
# [5]	train-rmse:0.448986	test-rmse:0.487307	train-error:0.01978	test-error:0.070175
# [6]	train-rmse:0.56289	test-rmse:0.596039	train-error:0.013187	test-error:0.052632
# [7]	train-rmse:0.674882	test-rmse:0.698743	train-error:0.008791	test-error:0.052632
# [8]	train-rmse:0.785773	test-rmse:0.805449	train-error:0.008791	test-error:0.052632
# [9]	train-rmse:0.89346	test-rmse:0.906848	train-error:0.008791	test-error:0.052632
# [10]	train-rmse:0.997078	test-rmse:1.00828	train-error:0.008791	test-error:0.052632
# [11]	train-rmse:1.10112	test-rmse:1.10701	train-error:0.008791	test-error:0.061404
# [12]	train-rmse:1.20159	test-rmse:1.20548	train-error:0.008791	test-error:0.061404
# [13]	train-rmse:1.29975	test-rmse:1.30221	train-error:0.008791	test-error:0.061404
# [14]	train-rmse:1.39635	test-rmse:1.39934	train-error:0.008791	test-error:0.061404
# [15]	train-rmse:1.49252	test-rmse:1.49343	train-error:0.008791	test-error:0.052632
# [16]	train-rmse:1.58706	test-rmse:1.58827	train-error:0.006593	test-error:0.04386
# [17]	train-rmse:1.67998	test-rmse:1.68171	train-error:0.006593	test-error:0.04386
# [18]	train-rmse:1.7721	test-rmse:1.77251	train-error:0.006593	test-error:0.04386
# [19]	train-rmse:1.86186	test-rmse:1.8642	train-error:0.006593	test-error:0.04386
# [20]	train-rmse:1.95014	test-rmse:1.95455	train-error:0.006593	test-error:0.04386
# [21]	train-rmse:2.03547	test-rmse:2.0396	train-error:0.006593	test-error:0.04386
# [22]	train-rmse:2.12162	test-rmse:2.12708	train-error:0.006593	test-error:0.04386
# [23]	train-rmse:2.20666	test-rmse:2.21203	train-error:0.006593	test-error:0.04386
# [24]	train-rmse:2.28555	test-rmse:2.28592	train-error:0.006593	test-error:0.04386
# [25]	train-rmse:2.36331	test-rmse:2.36768	train-error:0.006593	test-error:0.04386
# [26]	train-rmse:2.44355	test-rmse:2.44961	train-error:0.006593	test-error:0.04386
# [27]	train-rmse:2.52208	test-rmse:2.52977	train-error:0.006593	test-error:0.04386
# [28]	train-rmse:2.59905	test-rmse:2.6088	train-error:0.006593	test-error:0.04386
# [29]	train-rmse:2.67691	test-rmse:2.68466	train-error:0.006593	test-error:0.052632
# [30]	train-rmse:2.74564	test-rmse:2.75219	train-error:0.006593	test-error:0.04386
# [31]	train-rmse:2.81833	test-rmse:2.82331	train-error:0.004396	test-error:0.04386
# [32]	train-rmse:2.88818	test-rmse:2.88784	train-error:0.006593	test-error:0.035088
# [33]	train-rmse:2.9564	test-rmse:2.95681	train-error:0.004396	test-error:0.04386
# [34]	train-rmse:3.02544	test-rmse:3.02452	train-error:0.002198	test-error:0.04386
# [35]	train-rmse:3.09308	test-rmse:3.09235	train-error:0.004396	test-error:0.04386
# [36]	train-rmse:3.14191	test-rmse:3.13684	train-error:0.002198	test-error:0.04386
# [37]	train-rmse:3.2138	test-rmse:3.20654	train-error:0.002198	test-error:0.04386
# [38]	train-rmse:3.27486	test-rmse:3.26926	train-error:0.002198	test-error:0.04386
# [39]	train-rmse:3.33959	test-rmse:3.33323	train-error:0.002198	test-error:0.04386
# [40]	train-rmse:3.39526	test-rmse:3.38706	train-error:0.002198	test-error:0.04386
# [41]	train-rmse:3.45497	test-rmse:3.44893	train-error:0.004396	test-error:0.04386
# [42]	train-rmse:3.50582	test-rmse:3.49042	train-error:0.002198	test-error:0.04386
# [43]	train-rmse:3.55785	test-rmse:3.5422	train-error:0.002198	test-error:0.04386
# [44]	train-rmse:3.60552	test-rmse:3.59116	train-error:0.002198	test-error:0.04386
# [45]	train-rmse:3.65956	test-rmse:3.64325	train-error:0	test-error:0.04386
# [46]	train-rmse:3.70681	test-rmse:3.68944	train-error:0	test-error:0.04386
# [47]	train-rmse:3.76599	test-rmse:3.74543	train-error:0	test-error:0.04386
# [48]	train-rmse:3.81496	test-rmse:3.79703	train-error:0	test-error:0.04386
# [49]	train-rmse:3.86701	test-rmse:3.84457	train-error:0	test-error:0.04386

# %% [markdown]
# ### 4、交叉验证

# %%
params = {
    "objective":"binary:logistic",
    "booster":"gbtree",
    "eta": 0.1,
    "max_depth": 5
}
num_round = 50

# %% [markdown]
# xgboost利用cv函数进行交叉验证，nfold参数为交叉验证中数据集被分为nfold份，metrics是交叉验证使用的评估指标，callbacks可以定义多个callback函数，会在每一轮迭代的最后被调用，用户也可以使用xgboost内置的callback函数

# %%
res = xgb.cv(params,xgb_train,num_round,nfold=5,metrics={'auc'},seed=0,
             callbacks=[xgb.callback.print_evaluation(show_stdv=True)]) #xgb.callback.print_evaluation(show_stdv=True):打印评估指标的均值+标准差
# Out:
# [0]	train-auc:0.996496+0.00175595	test-auc:0.962077+0.0177871
# [1]	train-auc:0.996454+0.00177517	test-auc:0.963754+0.0200165
# [2]	train-auc:0.996424+0.00179116	test-auc:0.964545+0.0198595
# [3]	train-auc:0.996979+0.00189768	test-auc:0.963221+0.0218959
# [4]	train-auc:0.996952+0.00191968	test-auc:0.964236+0.0240807
# [5]	train-auc:0.999015+0.000712626	test-auc:0.966035+0.0234331
# [6]	train-auc:0.999116+0.000696901	test-auc:0.968592+0.0240493
# [7]	train-auc:0.999345+0.00072586	test-auc:0.967956+0.0241695
# [8]	train-auc:0.99948+0.000565826	test-auc:0.967996+0.0244328
# [9]	train-auc:0.999474+0.000573455	test-auc:0.968494+0.0247489
# [10]	train-auc:0.999487+0.000557343	test-auc:0.968599+0.0247509
# [11]	train-auc:0.999719+0.000368483	test-auc:0.967738+0.0258376
# [12]	train-auc:0.999835+0.000198995	test-auc:0.967957+0.0255959
# [13]	train-auc:0.999874+0.000174767	test-auc:0.967434+0.0261129
# [14]	train-auc:0.999941+6.44962e-05	test-auc:0.968084+0.0250049
# [15]	train-auc:0.999974+3.77306e-05	test-auc:0.974219+0.0209291
# [16]	train-auc:0.999981+3.88e-05	test-auc:0.974204+0.0206516
# [17]	train-auc:0.999981+3.88e-05	test-auc:0.976253+0.0201259
# [18]	train-auc:0.999994+1.28e-05	test-auc:0.975778+0.0202383
# [19]	train-auc:1+0	test-auc:0.97664+0.0200658
# [20]	train-auc:1+0	test-auc:0.976759+0.0200928
# [21]	train-auc:1+0	test-auc:0.97707+0.020074
# [22]	train-auc:1+0	test-auc:0.97729+0.020183
# [23]	train-auc:1+0	test-auc:0.977792+0.0200439
# [24]	train-auc:1+0	test-auc:0.979188+0.0179232
# [25]	train-auc:1+0	test-auc:0.978862+0.017747
# [26]	train-auc:1+0	test-auc:0.978875+0.0178294
# [27]	train-auc:1+0	test-auc:0.97877+0.0176831
# [28]	train-auc:1+0	test-auc:0.978785+0.0178142
# [29]	train-auc:1+0	test-auc:0.978785+0.0178142
# [30]	train-auc:1+0	test-auc:0.980655+0.0146828
# [31]	train-auc:1+0	test-auc:0.980409+0.0145344
# [32]	train-auc:1+0	test-auc:0.980515+0.0145359
# [33]	train-auc:1+0	test-auc:0.980904+0.0145309
# [34]	train-auc:1+0	test-auc:0.981103+0.014451
# [35]	train-auc:1+0	test-auc:0.981316+0.0142244
# [36]	train-auc:1+0	test-auc:0.981415+0.0141899
# [37]	train-auc:1+0	test-auc:0.981196+0.014382
# [38]	train-auc:1+0	test-auc:0.981091+0.014252
# [39]	train-auc:1+0	test-auc:0.981189+0.0143563
# [40]	train-auc:1+0	test-auc:0.981189+0.0143563
# [41]	train-auc:1+0	test-auc:0.981133+0.0147536
# [42]	train-auc:1+0	test-auc:0.981133+0.0147536
# [43]	train-auc:1+0	test-auc:0.980934+0.0148123
# [44]	train-auc:1+0	test-auc:0.981033+0.0147817
# [45]	train-auc:1+0	test-auc:0.98109+0.0146862
# [46]	train-auc:1+0	test-auc:0.981232+0.0147282
# [47]	train-auc:1+0	test-auc:0.981118+0.01462
# [48]	train-auc:1+0	test-auc:0.981118+0.01462
# [49]	train-auc:1+0	test-auc:0.981104+0.0147936

# %%
# 不输出标准差，若5轮评估指标未提升则停止训练
res = xgb.cv(params,xgb_train,num_round,nfold=5,metrics={'auc'},seed=0,callbacks=[xgb.callback.print_evaluation(show_stdv=False),xgb.callback.early_stop(5)])
# Out:
# [0]	train-auc:0.996496	test-auc:0.962077
# Multiple eval metrics have been passed: 'test-auc' will be used for early stopping.
#
# Will train until test-auc hasn't improved in 5 rounds.
# [1]	train-auc:0.996454	test-auc:0.963754
# [2]	train-auc:0.996424	test-auc:0.964545
# [3]	train-auc:0.996979	test-auc:0.963221
# [4]	train-auc:0.996952	test-auc:0.964236
# [5]	train-auc:0.999015	test-auc:0.966035
# [6]	train-auc:0.999116	test-auc:0.968592
# [7]	train-auc:0.999345	test-auc:0.967956
# [8]	train-auc:0.99948	test-auc:0.967996
# [9]	train-auc:0.999474	test-auc:0.968494
# [10]	train-auc:0.999487	test-auc:0.968599
# [11]	train-auc:0.999719	test-auc:0.967738
# [12]	train-auc:0.999835	test-auc:0.967957
# [13]	train-auc:0.999874	test-auc:0.967434
# [14]	train-auc:0.999941	test-auc:0.968084
# [15]	train-auc:0.999974	test-auc:0.974219
# [16]	train-auc:0.999981	test-auc:0.974204
# [17]	train-auc:0.999981	test-auc:0.976253
# [18]	train-auc:0.999994	test-auc:0.975778
# [19]	train-auc:1	test-auc:0.97664
# [20]	train-auc:1	test-auc:0.976759
# [21]	train-auc:1	test-auc:0.97707
# [22]	train-auc:1	test-auc:0.97729
# [23]	train-auc:1	test-auc:0.977792
# [24]	train-auc:1	test-auc:0.979188
# [25]	train-auc:1	test-auc:0.978862
# [26]	train-auc:1	test-auc:0.978875
# [27]	train-auc:1	test-auc:0.97877
# [28]	train-auc:1	test-auc:0.978785
# [29]	train-auc:1	test-auc:0.978785
# Stopping. Best iteration:
# [24]	train-auc:1+0	test-auc:0.979188+0.0179232

# %%
print(res)
# Out:
#     train-auc-mean  train-auc-std  test-auc-mean  test-auc-std
# 0         0.996496       0.001756       0.962077      0.017787
# 1         0.996454       0.001775       0.963754      0.020016
# 2         0.996424       0.001791       0.964545      0.019859
# 3         0.996979       0.001898       0.963221      0.021896
# 4         0.996952       0.001920       0.964236      0.024081
# 5         0.999015       0.000713       0.966035      0.023433
# 6         0.999116       0.000697       0.968592      0.024049
# 7         0.999345       0.000726       0.967956      0.024170
# 8         0.999480       0.000566       0.967996      0.024433
# 9         0.999474       0.000573       0.968494      0.024749
# 10        0.999487       0.000557       0.968599      0.024751
# 11        0.999719       0.000368       0.967738      0.025838
# 12        0.999835       0.000199       0.967957      0.025596
# 13        0.999874       0.000175       0.967434      0.026113
# 14        0.999941       0.000064       0.968084      0.025005
# 15        0.999974       0.000038       0.974219      0.020929
# 16        0.999981       0.000039       0.974204      0.020652
# 17        0.999981       0.000039       0.976253      0.020126
# 18        0.999994       0.000013       0.975778      0.020238
# 19        1.000000       0.000000       0.976640      0.020066
# 20        1.000000       0.000000       0.976759      0.020093
# 21        1.000000       0.000000       0.977070      0.020074
# 22        1.000000       0.000000       0.977290      0.020183
# 23        1.000000       0.000000       0.977792      0.020044
# 24        1.000000       0.000000       0.979188      0.017923

# %% [markdown]
# xgboost的交叉验证还支持自定义预处理函数

# %%
def fpreproc(xgb_train,xgb_test,params):
  label = xgb_train.get_label()
  ratio = float(np.sum(label==0))/np.sum(label==1)
  params['scale_pos_weight'] = ratio #设置参数scale_pos_weight
  return (xgb_train,xgb_test,params)

xgb.cv(params,xgb_train,num_round,nfold=5,metrics={'auc'},seed=0,fpreproc=fpreproc)
# Out:
#     train-auc-mean  train-auc-std  test-auc-mean  test-auc-std
# 0         0.995407       0.001344       0.953464      0.013351
# 1         0.995437       0.001356       0.953549      0.013661
# 2         0.998148       0.001816       0.965869      0.022223
# 3         0.999094       0.001178       0.972817      0.016854
# 4         0.999014       0.001167       0.974063      0.016056
# 5         0.999080       0.001115       0.975040      0.015884
# 6         0.999474       0.000588       0.976908      0.013069
# 7         0.999500       0.000632       0.977014      0.012762
# 8         0.999787       0.000287       0.977067      0.012741
# 9         0.999895       0.000138       0.977106      0.013299
# 10        0.999935       0.000069       0.977771      0.013487
# 11        0.999954       0.000044       0.977884      0.013566
# 12        0.999967       0.000029       0.978156      0.013581
# 13        0.999980       0.000016       0.978043      0.014050
# 14        0.999980       0.000016       0.979220      0.013975
# 15        0.999987       0.000016       0.980033      0.014300
# 16        0.999987       0.000016       0.980245      0.014327
# 17        0.999987       0.000016       0.979912      0.015033
# 18        0.999987       0.000016       0.979767      0.015265
# 19        0.999987       0.000016       0.979767      0.015265
# 20        0.999987       0.000016       0.979888      0.015429
# 21        0.999993       0.000013       0.980001      0.015524
# 22        0.999993       0.000013       0.980313      0.014993
# 23        0.999993       0.000013       0.980313      0.015295
# 24        0.999993       0.000013       0.980215      0.015201
# 25        0.999993       0.000013       0.980004      0.015317
# 26        0.999993       0.000013       0.980414      0.015339
# 27        0.999993       0.000013       0.980611      0.015862
# 28        1.000000       0.000000       0.980611      0.015862
# 29        1.000000       0.000000       0.981035      0.016006
# 30        1.000000       0.000000       0.981035      0.016006
# 31        1.000000       0.000000       0.981333      0.015996
# 32        1.000000       0.000000       0.983940      0.011099
# 33        1.000000       0.000000       0.983840      0.011244
# 34        1.000000       0.000000       0.984067      0.010840
# 35        1.000000       0.000000       0.984499      0.010437
# 36        1.000000       0.000000       0.984910      0.010445
# 37        1.000000       0.000000       0.985647      0.009131
# 38        1.000000       0.000000       0.986894      0.007053
# 39        1.000000       0.000000       0.986894      0.007053
# 40        1.000000       0.000000       0.985874      0.008737
# 41        1.000000       0.000000       0.985647      0.009131
# 42        1.000000       0.000000       0.984797      0.010650
# 43        1.000000       0.000000       0.984626      0.010961
# 44        1.000000       0.000000       0.984527      0.010983
# 45        1.000000       0.000000       0.984641      0.010777
# 46        1.000000       0.000000       0.984591      0.010790
# 47        1.000000       0.000000       0.984818      0.010383
# 48        1.000000       0.000000       0.984831      0.010525
# 49        1.000000       0.000000       0.984718      0.010725

# %%
#用户自定义目标函数和评估函数来交叉验证，继续延用之前的目标函数
xgb.cv(params,xgb_train,num_round,nfold=5,obj=logregobj,feval=evalerror)
# Out:
#     train-error-mean  train-error-std  ...  test-rmse-mean  test-rmse-std
# 0           0.364835         0.013725  ...        0.361129       0.009725
# 1           0.364835         0.013725  ...        0.261732       0.033812
# 2           0.066484         0.003645  ...        0.240469       0.053229
# 3           0.039561         0.010654  ...        0.287616       0.046761
# 4           0.026923         0.008038  ...        0.376795       0.043140
# 5           0.020330         0.006408  ...        0.475815       0.039896
# 6           0.017033         0.006360  ...        0.580189       0.040293
# 7           0.015385         0.006407  ...        0.683859       0.043168
# 8           0.014286         0.005327  ...        0.787032       0.042268
# 9           0.013187         0.004395  ...        0.889679       0.042320
# 10          0.012088         0.003726  ...        0.987769       0.044338
# 11          0.010989         0.003009  ...        1.084597       0.045103
# 12          0.009341         0.003296  ...        1.177966       0.044381
# 13          0.008242         0.003885  ...        1.271822       0.045453
# 14          0.007143         0.003727  ...        1.362934       0.046605
# 15          0.007143         0.003727  ...        1.449882       0.048647
# 16          0.007143         0.003727  ...        1.537453       0.053376
# 17          0.006593         0.003297  ...        1.623167       0.054418
# 18          0.006044         0.003204  ...        1.710780       0.056668
# 19          0.005495         0.002457  ...        1.795641       0.057544
# 20          0.005495         0.002457  ...        1.878269       0.061050
# 21          0.005495         0.002457  ...        1.960733       0.062402
# 22          0.005495         0.002457  ...        2.042330       0.066648
# 23          0.004945         0.002056  ...        2.119533       0.070888
# 24          0.004945         0.002056  ...        2.198590       0.072587
# 25          0.004945         0.002056  ...        2.273746       0.075668
# 26          0.004396         0.002198  ...        2.351750       0.078787
# 27          0.003846         0.001346  ...        2.423010       0.083849
# 28          0.003846         0.001346  ...        2.493618       0.086982
# 29          0.003846         0.001346  ...        2.566973       0.086963
# 30          0.003297         0.001099  ...        2.633604       0.092112
# 31          0.003297         0.001099  ...        2.703701       0.095422
# 32          0.002747         0.000000  ...        2.769422       0.093789
# 33          0.002747         0.000000  ...        2.833251       0.095259
# 34          0.002747         0.000000  ...        2.895786       0.098802
# 35          0.002747         0.000000  ...        2.955605       0.098760
# 36          0.002747         0.000000  ...        3.017744       0.101889
# 37          0.002747         0.000000  ...        3.073956       0.110189
# 38          0.002198         0.001099  ...        3.132091       0.109169
# 39          0.001648         0.001346  ...        3.189516       0.110817
# 40          0.001648         0.001346  ...        3.241697       0.107519
# 41          0.001648         0.001346  ...        3.298833       0.107221
# 42          0.001099         0.001346  ...        3.350595       0.112297
# 43          0.001099         0.001346  ...        3.402179       0.116873
# 44          0.001099         0.001346  ...        3.444739       0.114052
# 45          0.001099         0.001346  ...        3.492502       0.112358
# 46          0.000549         0.001099  ...        3.541309       0.116564
# 47          0.000549         0.001099  ...        3.586854       0.119404
# 48          0.000549         0.001099  ...        3.633594       0.125763
# 49          0.000549         0.001099  ...        3.677280       0.121570
#
# [50 rows x 8 columns]

# %% [markdown]
# ### 5、保存评估结果
# 模型保存与评估结果保存

# %%
model = xgb.train(params,xgb_train,10,watchlist)
model.save_model("./model.xgb")
# Out:
# [0]	train-error:0.004396	test-error:0.04386
# [1]	train-error:0.004396	test-error:0.04386
# [2]	train-error:0.004396	test-error:0.04386
# [3]	train-error:0.004396	test-error:0.04386
# [4]	train-error:0.004396	test-error:0.035088
# [5]	train-error:0.004396	test-error:0.035088
# [6]	train-error:0.004396	test-error:0.035088
# [7]	train-error:0.004396	test-error:0.04386
# [8]	train-error:0.004396	test-error:0.04386
# [9]	train-error:0.004396	test-error:0.04386

# %%
bst = xgb.Booster()
bst.load_model("./model.xgb")
pred = bst.predict(xgb_test)
pred
# Out:
# array([0.9303397 , 0.9119321 , 0.9303397 , 0.8942841 , 0.92795146,
#        0.9303397 , 0.4654373 , 0.46111533, 0.9303397 , 0.9303397 ,
#        0.91980803, 0.9303397 , 0.9303397 , 0.07041784, 0.07041784,
#        0.9303397 , 0.89680326, 0.07595936, 0.5600603 , 0.07041784,
#        0.7233341 , 0.19820791, 0.72285205, 0.9303397 , 0.9303397 ,
#        0.3644025 , 0.07041784, 0.07041784, 0.9303397 , 0.8813913 ,
#        0.9303397 , 0.9303397 , 0.08022156, 0.07041784, 0.0756431 ,
#        0.92710835, 0.0839306 , 0.07041784, 0.8252453 , 0.07041784,
#        0.9303397 , 0.0756431 , 0.09421231, 0.9303397 , 0.59778714,
#        0.9303397 , 0.8805882 , 0.07041784, 0.07041784, 0.07041784,
#        0.5872261 , 0.10664127, 0.9087783 , 0.1211081 , 0.9257959 ,
#        0.07041784, 0.07041784, 0.92458844, 0.9303397 , 0.9303397 ,
#        0.07041784, 0.07041784, 0.9303397 , 0.74109215, 0.9303397 ,
#        0.9303397 , 0.92458844, 0.12638171, 0.9303397 , 0.86494315,
#        0.09925666, 0.9028226 , 0.07041784, 0.9303397 , 0.07041784,
#        0.90846944, 0.07041784, 0.92795146, 0.9303397 , 0.9303397 ,
#        0.07041784, 0.09225376, 0.92710835, 0.07595936, 0.9303397 ,
#        0.9303397 , 0.8380674 , 0.07041784, 0.9287544 , 0.07041784,
#        0.9303397 , 0.9303397 , 0.08599456, 0.9161836 , 0.9303397 ,
#        0.19569229, 0.55207366, 0.8942841 , 0.9303397 , 0.07041784,
#        0.9303397 , 0.07041784, 0.9246184 , 0.07041784, 0.9303397 ,
#        0.7149689 , 0.9303397 , 0.07041784, 0.9303397 , 0.9303397 ,
#        0.7636961 , 0.9303397 , 0.9303397 , 0.92795146], dtype=float32)

# %%
dump_model = bst.dump_model("./dump.txt") #将模型保存为文本格式

# %% [markdown]
# 评估结果的保存

# %%
evals_result = {} #定义dict类型保存评估指标
bst = xgb.train(params,xgb_train,num_round,watchlist,evals_result=evals_result)
print(evals_result)
# Out:
# [0]	train-error:0.004396	test-error:0.04386
# [1]	train-error:0.004396	test-error:0.04386
# [2]	train-error:0.004396	test-error:0.04386
# [3]	train-error:0.004396	test-error:0.04386
# [4]	train-error:0.004396	test-error:0.035088
# [5]	train-error:0.004396	test-error:0.035088
# [6]	train-error:0.004396	test-error:0.035088
# [7]	train-error:0.004396	test-error:0.04386
# [8]	train-error:0.004396	test-error:0.04386
# [9]	train-error:0.004396	test-error:0.04386
# {'train': {'error': [0.004396, 0.004396, 0.004396, 0.004396, 0.004396, 0.004396, 0.004396, 0.004396, 0.004396, 0.004396]}, 'test': {'error': [0.04386, 0.04386, 0.04386, 0.04386, 0.035088, 0.035088, 0.035088, 0.04386, 0.04386, 0.04386]}}

# %% [markdown]
# ### 6、通过前n棵树预测

# %%
from sklearn.metrics import roc_auc_score

# %%
params = {
    "objective":"binary:logistic",
    "booster":"gbtree",
    "eta": 0.1,
    "max_depth": 5
}
num_round = 50
watchlist = [(xgb_test,'eval'),(xgb_train,'train')]

# %%
bst = xgb.train(params,xgb_train,num_round,watchlist)
print('前10棵树预测')
label = xgb_test.get_label()
pred1 = bst.predict(xgb_test,ntree_limit=10) 
#默认情况用所有树预测
pred2 = bst.predict(xgb_test)
print("前10棵树auc：%f" %roc_auc_score(y_test,pred1))
print("所有棵树auc：%f" %roc_auc_score(y_test,pred2))
# Out:
# [0]	eval-error:0.035088	train-error:0.024176
# [1]	eval-error:0.052632	train-error:0.015385
# [2]	eval-error:0.070175	train-error:0.013187
# [3]	eval-error:0.078947	train-error:0.004396
# [4]	eval-error:0.078947	train-error:0.004396
# [5]	eval-error:0.04386	train-error:0.004396
# [6]	eval-error:0.052632	train-error:0.004396
# [7]	eval-error:0.061404	train-error:0.004396
# [8]	eval-error:0.052632	train-error:0.004396
# [9]	eval-error:0.04386	train-error:0.004396
# [10]	eval-error:0.04386	train-error:0.004396
# [11]	eval-error:0.04386	train-error:0.004396
# [12]	eval-error:0.04386	train-error:0.004396
# [13]	eval-error:0.04386	train-error:0.004396
# [14]	eval-error:0.035088	train-error:0.004396
# [15]	eval-error:0.035088	train-error:0.004396
# [16]	eval-error:0.035088	train-error:0.004396
# [17]	eval-error:0.04386	train-error:0.004396
# [18]	eval-error:0.04386	train-error:0.004396
# [19]	eval-error:0.04386	train-error:0.004396
# [20]	eval-error:0.04386	train-error:0.004396
# [21]	eval-error:0.04386	train-error:0.004396
# [22]	eval-error:0.04386	train-error:0.004396
# [23]	eval-error:0.04386	train-error:0.004396
# [24]	eval-error:0.04386	train-error:0.004396
# [25]	eval-error:0.04386	train-error:0.004396
# [26]	eval-error:0.04386	train-error:0.004396
# [27]	eval-error:0.035088	train-error:0.004396
# [28]	eval-error:0.035088	train-error:0.004396
# [29]	eval-error:0.04386	train-error:0.004396
# [30]	eval-error:0.04386	train-error:0.004396
# [31]	eval-error:0.04386	train-error:0.004396
# [32]	eval-error:0.04386	train-error:0.004396
# [33]	eval-error:0.04386	train-error:0.002198
# [34]	eval-error:0.04386	train-error:0.002198
# [35]	eval-error:0.04386	train-error:0.002198
# [36]	eval-error:0.04386	train-error:0.002198
# [37]	eval-error:0.04386	train-error:0.002198
# [38]	eval-error:0.04386	train-error:0.002198
# [39]	eval-error:0.04386	train-error:0.002198
# [40]	eval-error:0.04386	train-error:0.002198
# [41]	eval-error:0.04386	train-error:0.002198
# [42]	eval-error:0.04386	train-error:0.002198
# [43]	eval-error:0.04386	train-error:0.002198
# [44]	eval-error:0.04386	train-error:0.002198
# [45]	eval-error:0.04386	train-error:0.002198
# [46]	eval-error:0.04386	train-error:0.002198
# [47]	eval-error:0.04386	train-error:0
# [48]	eval-error:0.04386	train-error:0
# [49]	eval-error:0.04386	train-error:0
# 前10棵树预测
# 前10棵树auc：0.995205
# 所有棵树auc：0.997123
